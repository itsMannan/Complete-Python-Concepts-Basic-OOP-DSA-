# %% [markdown]
# # Python Variables

# %% [markdown]
# # Variables
#
# Variables are containers for storing data values.

# %% [markdown]
# # Creating Variables
#
# Python has no command for declaring a variable.
#
# A variable is created the moment you first assign a value to it.

# %%
x = 5
y = "John"
print(x)
print(y)
# Out:
# 5
# John

# %% [markdown]
# Variables do not need to be declared with any particular type, and can even change type after they have been set.

# %%
x = 4           # x is type of int
x = "Sally"     # x is now type of str
print(x)
# Out:
# Sally

# %% [markdown]
# # Casting
#
# If you want to specify the data type of a variable, this can be done with casting.

# %%
x = 3   # x type is int
y = 3   # y type is int
z = 3   # z type is int

# %%
x = str(3)
y = float(3)
z = int(3)
print(x); print(y); print(z)
# Out:
# 3
# 3.0
# 3

# %% [markdown]
# # Get the Type
#
# You can get the data type of a variable with the type() function.

# %%
x = str(3)
y = float(3)
z = int(3)
print(type(x)); print(type(y)); print(type(z))
# Out:
# <class 'str'>
# <class 'float'>
# <class 'int'>

# %% [markdown]
# # Single or Double Quotes?
#
# String variables can be declared either by using single or double quotes:

# %%
x = "John"
print(x)
# is same as

x = 'John'
print(x)
# Out:
# John
# John

# %% [markdown]
# # Case-Sensitive
#
# Variable names are case-sensitive (a system distinguishes between uppercase (A, B, C) and lowercase (a, b, c) letters, treating them as different characters).

# %%
a = 4
print(a)
A = "Sally"
print(A)
# A will not overwrite a
# Out:
# 4
# Sally

# %% [markdown]
# # Python - Variable Names

# %% [markdown]
# # Variable Names
#
# A variable can have a short name (like x and y) or a more descriptive name (age, carname, total_volume).
#
# Rules for Python variables:
#
#     A variable name must start with a letter or the underscore character
#
#     A variable name cannot start with a number
#
#     A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
#
#     Variable names are case-sensitive (age, Age and AGE are three different variables)
#
#     A variable name cannot be any of the Python keywords.

# %% [markdown]
# # Legal variables names:

# %%
myvar = "John"
print(myvar)

my_var = "John"
print(my_var)

_my_var = "John"

myVar = "John"
print(myVar)

MYVAR = "John"
print(MYVAR)

myvar2 = "John"
print(myvar2)

_ = "John"
print(_)
# Out:
# John
# John
# John
# John
# John
# John

# %% [markdown]
# # llegal variable names:

# %%
2myvar = "John"
my-var = "John"
my var = "John"

print(2myvar)
print(my-var)
print(my var)
# Out:
#   Cell In[20], line 1
#     2myvar = "John"
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# Remember that variable names are case-sensitive

# %% [markdown]
# # Multi Words Variable Names
#
# Variable names with more than one word can be difficult to read.
#
# There are several techniques you can use to make them more readable:

# %% [markdown]
# # 1. Camel Case
#
# Each word, except the first, starts with a capital letter:

# %%
myVariableName = "John"
print(myVariableName)

abdulMannanAsif = "Human and Muslim"
print(abdulMannanAsif)
# Out:
# John
# Human and Muslim

# %% [markdown]
# # 2. Pascal Case
#
# Each word starts with a capital letter:

# %%
MyVariableName = "John"
print(MyVariableName)
# Out:
# John

# %% [markdown]
# # 3. Snake Case
#
# Each word is separated by an underscore character:

# %%
my_variable_name = "John"
print(my_variable_name)
# Out:
# John

# %% [markdown]
# # Python Variables - Assign Multiple Values

# %% [markdown]
# # Many Values to Multiple Variables
#
# Python allows you to assign values to multiple variables in one line:

# %%
x, y, z = "Orange", "Banana", "Cherry"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry

# %% [markdown]
# * Note: Make sure the number of variables matches the number of values, or else you will get an error.

# %% [markdown]
# # One Value to Multiple Variables
#
# And you can assign the same value to multiple variables in one line:

# %%
x = y = z = "Orange"
a = b = c = 5
print(a, end = " ")
print(x)
print(b, end = " ")
print(y)
print(c, end = " ")
print(z)
# Out:
# 5 Orange
# 5 Orange
# 5 Orange

# %% [markdown]
# # Unpack a Collection
#
# If you have a collection of values in a list, tuple etc. Python allows you to extract the values into variables. This is called unpacking.

# %%
fruits = ["apple", "banana", "cherry"]
x , y , z = fruits
print(x)
print(y)
print(z)
#-------------------------------------
#-------------------------------------
numbers = (1,2,3)
a , b , c = numbers
print(a)
print(b)
print(c)
# Out:
# apple
# banana
# cherry
# 1
# 2
# 3

# %% [markdown]
# # Python - Output Variables

# %% [markdown]
# # Output Variables
#
# The print() function is often used to output variables.

# %%
x = "Python is awesome"
print(x)
# Out:
# Python is awesome

# %% [markdown]
# In the print() function, you output multiple variables, separated by a comma:

# %%
x = "Python"
y = "is"
z = "awesome"
print(x, y, z)
# Out:
# Python is awesome

# %% [markdown]
# You can also use the + operator to output multiple variables:

# %%
x = "Python"
y = "is"
z = "awesome"
print(x + y + z)
# Out:
# Pythonisawesome

# %% [markdown]
# Notice the space character after "Python " and "is ", without them the result would be "Pythonisawesome".

# %%
x = "Python "
y = "is "
z = "awesome"
print(x + y + z)
# Out:
# Python is awesome

# %% [markdown]
# For numbers, the + character works as a mathematical operator:

# %%
x = 5 
y = 10
print(x + y)
# Out:
# 15

# %% [markdown]
# In the print() function, when you try to combine a string and a number with the + operator, Python will give you an error:

# %%
x = 5
y = "John"
print(x + y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 3
#       1 x = 5
#       2 y = "John"
# ----> 3 print(x + y)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# The best way to output multiple variables in the print() function is to separate them with commas, which even support different data types:

# %%
x = 5
y = "John"
print(x, y)
# Out:
# 5 John

# %% [markdown]
# # Python - Global Variables

# %% [markdown]
# # Global Variables
#
# Variables that are created outside of a function (as in all of the examples in the previous pages) are known as global variables.
#
# Global variables can be used by everyone, both inside of functions and outside.

# %% [markdown]
# * Example
#
# Create a variable outside of a function, and use it inside the function

# %%
x = "awesome"

def myfunc():
    print("Python is", x)
    
myfunc()
# Out:
# Python is awesome

# %% [markdown]
# If you create a variable with the same name inside a function, this variable will be local, and can only be used inside the function. The global variable with the same name will remain as it was, global and with the original value.

# %% [markdown]
# * Example
#
# Create a variable inside a function, with the same name as the global variable

# %%
x = "awesome"

def myfunc():
    x = "fantastic"
    print("Python is", x)
    
myfunc()

print("Pyhton is", x)
# Out:
# Python is fantastic
# Pyhton is awesome

# %% [markdown]
# # The Global Keyword
#
# Normally, when you create a variable inside a function, that variable is local, and can only be used inside the function
#
# To create a global variable inside a function, you can use the "global" variable

# %% [markdown]
# * Example
#
# if you use the global keyword, the variable belongs to the global scope:

# %%
def myfunc():
    global x
    x = "fantastic"
    print("Python is", x)
    
myfunc()

print("Python is",x)
# Out:
# Python is fantastic
# Python is fantastic

# %% [markdown]
# Also, use the global keyword if you want to change a global variable inside a function.

# %% [markdown]
# * Example
#
# To change the value of a global variable inside a function, refer to the variable by using the global keyword:

# %%
x = "awesome"

def myfunc():
    global x
    x = "fantastic"
    print("Python is", x)
    
myfunc()

print("Java is", x)
# Out:
# Python is fantastic
# Java is fantastic

# %% [markdown]
# # Python Data Types

# %% [markdown]
# # Built-in Data Types
#
# In programming, data type is an important concept.
#
# Variables can store data of different types, and different types can do different things.
#
# Python has the following data types built-in by default, in these categories:
#
# 1. Text Type:	            str
# 2. Numeric Types:	        int, float, complex
# 3. Sequence Types:	        list, tuple, range
# 4. Mapping Type:	        dict
# 5. Set Types:	            set, frozenset
# 6. Boolean Type:	        bool
# 7. Binary Types:	        bytes, bytearray, memoryview
# 8. None Type:	            NoneType

# %% [markdown]
# # Getting the Data Type
#
# You can get the data type of any object by using the type() function:

# %% [markdown]
# * Example
#
# Print the data type of the variable x:

# %%
x = 5
print(type(x))
# Out:
# <class 'int'>

# %% [markdown]
# # Setting the Data Data Type
#
# In Python, the data type is set when you assign a value to a variable:

# %%
x = "Hello World"
print(x)
print(type(x))
# Out:
# Hello World
# <class 'str'>

# %%
x = 20
print(x)
print(type(x))
# Out:
# 20
# <class 'int'>

# %%
x = 20.5
print(x)
print(type(x))
# Out:
# 20.5
# <class 'float'>

# %%
x = 1j
print(x)
print(type(x))
# Out:
# 1j
# <class 'complex'>

# %%
x = ["apple","banana","cherry"]
print(x)
print(type(x))
# Out:
# ['apple', 'banana', 'cherry']
# <class 'list'>

# %%
x = ("apple", "banana", "cherry")
print(x)
print(type(x))
# Out:
# ('apple', 'banana', 'cherry')
# <class 'tuple'>

# %%
x = range(6)
print(x)
print(type(x))
# Out:
# range(0, 6)
# <class 'range'>

# %%
x = {
    'name' : 'Abdul Mannan',
    'age' : 24
}
print(x)
print(type(x))
# Out:
# {'name': 'Abdul Mannan', 'age': 24}
# <class 'dict'>

# %%
x = {"apple", "banana", "cheery"}
print(x)
print(type(x))
# Out:
# {'cheery', 'banana', 'apple'}
# <class 'set'>

# %%
x = frozenset({"apple", "banana", "cherry"})
print(x)
print(type(x))
# Out:
# frozenset({'cherry', 'banana', 'apple'})
# <class 'frozenset'>

# %%
x, y = True, False
print(x)
print(y)
print(type(x))
print(type(y))
# Out:
# True
# False
# <class 'bool'>
# <class 'bool'>

# %%
x = b"Hello"
print(x)
print(type(x))
# Out:
# b'Hello'
# <class 'bytes'>

# %%
x = bytearray(5)
print(x)
print(type(x))
# Out:
# bytearray(b'\x00\x00\x00\x00\x00')
# <class 'bytearray'>

# %%
x = memoryview (bytes(5))
print(x)
print(type(x))
# Out:
# <memory at 0x1066d5c00>
# <class 'memoryview'>

# %%
x = None
print(x)
print(type(x))
# Out:
# None
# <class 'NoneType'>

# %% [markdown]
# # Setting the Specific Data Type
#
# If you want to specify the data type, you can use the following constructor functions

# %%
x = str("Hello World")
print(x)
print(type(x))
# Out:
# Hello World
# <class 'str'>

# %%
x = int(20)
print(x)
print(type(x))
# Out:
# 20
# <class 'int'>

# %%
x = float(20.5)
print(x)
print(type(x))
# Out:
# 20.5
# <class 'float'>

# %%
x = complex(1j)
print(x)
print(type(x))
# Out:
# 1j
# <class 'complex'>

# %%
x = list(("apple", "Banana", "cherry"))
print(x)
print(type(x))
# Out:
# ['apple', 'Banana', 'cherry']
# <class 'list'>

# %%
x = tuple(("1", "2", "3"))
print(x)
print(type(x))
# Out:
# ('1', '2', '3')
# <class 'tuple'>

# %%
x = range(6)
print(x)
print(type(x))
# Out:
# range(0, 6)
# <class 'range'>

# %%
x = dict(name = 'John', age = 23)
print(x)
print(type(x))
# Out:
# {'name': 'John', 'age': 23}
# <class 'dict'>

# %%
x = set(("Abdullah", "Awais", "Azhar"))
print(x)
print(type(x))
# Out:
# {'Abdullah', 'Awais', 'Azhar'}
# <class 'set'>

# %%
x = frozenset(("Abdullah", "Awais", "Azhar"))
print(x)
print(type(x))
# Out:
# frozenset({'Abdullah', 'Awais', 'Azhar'})
# <class 'frozenset'>

# %%
x = bool(1)
y = bool(0)
print(x)
print(y)
print(type(x))
print(type(y))
# Out:
# True
# False
# <class 'bool'>
# <class 'bool'>

# %%
x = bytes(4)
print(x)
print(type(x))
# Out:
# b'\x00\x00\x00\x00'
# <class 'bytes'>

# %%
x = bytearray(5)
print(x)
print(type(x))
# Out:
# bytearray(b'\x00\x00\x00\x00\x00')
# <class 'bytearray'>

# %%
x = memoryview(bytes(5))
print(x)
print(type(x))
# Out:
# <memory at 0x106f8cd00>
# <class 'memoryview'>
