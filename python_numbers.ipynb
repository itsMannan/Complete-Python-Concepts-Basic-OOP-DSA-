# %% [markdown]
# # Python Numbers

# %% [markdown]
# ### Python Numbers
#
# There are three numeric types in Python:
#
# * int
# * float
# * complex
#
# Variables of numeric types are created when you assign a value to them:

# %%
x = 1   # int
y = 2.8 # float
z = 1j  # complex

print(x, type(x))
print(y, type(y))
print(z, type(z))
# Out:
# 1 <class 'int'>
# 2.8 <class 'float'>
# 1j <class 'complex'>

# %% [markdown]
# * #  Int
#
# Int, or integer is a whole number, positive or negative, without decimals, of unlimited length

# %%
x = 1
y = 35562445443232423
z = -23232232

print(x, type(x))
print(y, type(y))
print(z, type(z))
# Out:
# 1 <class 'int'>
# 35562445443232423 <class 'int'>
# -23232232 <class 'int'>

# %% [markdown]
# * # Float
#
# Float, or "floating point number" is a number, positive or negative, containing one or more decimals.

# %%
x = 1.10
y = 1.0
z = -35.59

print(x,type(x))
print(y,type(y))
print(z,type(z))
# Out:
# 1.1 <class 'float'>
# 1.0 <class 'float'>
# -35.59 <class 'float'>

# %% [markdown]
# * Float can also be scientific numbers with an "e" or "E" to indicate the power of 10.

# %%
x = 35e3
y = 12E4
z = -87.33e100

print(x,type(x))
print(y,type(y))
print(z,type(z))
# Out:
# 35000.0 <class 'float'>
# 120000.0 <class 'float'>
# -8.733e+101 <class 'float'>

# %% [markdown]
# * # Complex
#
# Complex numbers are written with a "j" as the imaginary part:

# %%
x = 3+5j
y = 5j
z = -5j

print(x,type(x))
print(y,type(y))
print(z,type(z))
# Out:
# (3+5j) <class 'complex'>
# 5j <class 'complex'>
# (-0-5j) <class 'complex'>

# %% [markdown]
# ## Type Coversion
#
# You can covert from one type to another with the int(), float(), and complex() methods:

# %%
x = 1
y = 2.8
z = 1j

print(x,type(x))
print(y,type(y))
print(z,type(z))

print("\n")

a = float(x)
b = int(y)
c = complex(x)

print(a,type(a))
print(b,type(b))
print(c,type(c))
# Out:
# 1 <class 'int'>
# 2.8 <class 'float'>
# 1j <class 'complex'>
#
#
# 1.0 <class 'float'>
# 2 <class 'int'>
# (1+0j) <class 'complex'>

# %% [markdown]
# * ### Note: You Cannot convert complex numbers into another number type.

# %% [markdown]
# # Random Numbers
#
# Python does not have a random() function to make a random number, but python has a built-in module called random that can be used make random numbers

# %%
import random

# %%
print(random.randrange(1,10))
print(random.randrange(2,5))
# Out:
# 3
# 2
